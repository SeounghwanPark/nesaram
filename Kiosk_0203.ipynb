# %% [markdown]
# <a href="https://colab.research.google.com/github/SeounghwanPark/nesaram/blob/main/Kiosk_0203.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
menu = ['americano', 'latte', 'mocha', 'yuza_tea', 'green_tea', 'choco_latte']
price = [2000, 3000, 3000, 2500, 2500, 3000]

class Kiosk:
    def __init__(self):
        self.menu = menu  # 메뉴 리스트
        self.price = price  # 가격 리스트
        self.price_sum = 0  # 선택한 음료의 가격(초기값)
        self.order_menu = []  # 주문 리스트
        self.order_price = []  # 가격 리스트

    def menu_print(self):
        """메뉴 출력"""
        print("\n 메뉴판")
        for i in range(len(self.menu)):
            print(f"{i+1}. {self.menu[i]} : {self.price[i]}원")

    def menu_select(self):
        """음료 선택 및 주문 추가"""
        while True:
            print("\n 음료를 선택하세요 (0 입력 시 주문 종료)")
            try:
                n = int(input("음료의 번호를 입력하세요 : "))
            except ValueError:
                print(" 숫자로 입력해주세요.\n")
                continue

            # 주문 종료
            if n == 0:
                print("\n🛒 주문이 완료되었습니다.")
                break

            # 유효한 메뉴 선택 확인
            if 1 <= n <= len(self.menu):
                selected_menu = self.menu[n-1]
                selected_price = self.price[n-1]
            else:
                print(" 없는 메뉴입니다. 다시 주문해 주세요.")
                continue

            # 음료 온도 선택
            t = 0
            while t not in [1, 2]:
                try:
                    t = int(input("HOT 음료는 1을, ICE 음료는 2를 입력하세요 : "))
                    if t == 1:
                        temp = "HOT"
                    elif t == 2:
                        temp = "ICE"
                    else:
                        print(" 1과 2 중 하나를 입력하세요.\n")
                except ValueError:
                    print(" 숫자로 입력해주세요.\n")

            # 주문 리스트에 추가
            self.order_menu.append(f"{temp} {selected_menu}")
            self.order_price.append(selected_price)

            print(f" {temp} {selected_menu} : {selected_price}원 주문이 추가되었습니다.")

        # 주문이 끝난 후 주문표 출력
        self.table()

    def table(self):
        """주문표 출력"""
        if not self.order_menu:  # 주문이 없을 경우
            print("\n 주문 내역이 없습니다.")
            return

        max_length = max(len(item) for item in self.order_menu) + 10
        total_price = sum(self.order_price)

        # 외곽 테두리 상단
        print('\n⟝' + '-' * max_length + '⟞')

        # 내부 여백 (위쪽)
        for _ in range(2):
            print('|' + ' ' * max_length + '|')

        # 주문 상품 출력
        for i in range(len(self.order_menu)):
            print(f"| {self.order_menu[i]:<{max_length-8}} : {self.order_price[i]:>5}원 |")

        # 합계 금액 출력
        print(f"| {'합계 금액':<{max_length-8}} : {total_price:>5}원 |")

        # 내부 여백 (아래쪽)
        for _ in range(2):
            print('|' + ' ' * max_length + '|')

        # 외곽 테두리 하단
        print('⟝' + '-' * max_length + '⟞\n')

    def pay(self):
        """지불"""
        total_price = sum(self.order_price)
        print(f"\n총 결제 금액은 {total_price}원 입니다.")
        # 여기에 결제 로직 추가
        print("결제가 완료되었습니다. ☕ 감사합니다!")


a = Kiosk()  # 객체 생성
a.menu_print()  # 메뉴 출력
a.menu_select()
a.pay()  # 지불
a.table()  # 주문표 출력
# Out:
#  메뉴판
# 1. americano : 2000원
# 2. latte : 3000원
# 3. mocha : 3000원
# 4. yuza_tea : 2500원
# 5. green_tea : 2500원
# 6. choco_latte : 3000원
#
#  음료를 선택하세요 (0 입력 시 주문 종료)
# 음료의 번호를 입력하세요 : 1
# HOT 음료는 1을, ICE 음료는 2를 입력하세요 : 2
#  ICE americano : 2000원 주문이 추가되었습니다.
#
#  음료를 선택하세요 (0 입력 시 주문 종료)
# 음료의 번호를 입력하세요 : 3
# HOT 음료는 1을, ICE 음료는 2를 입력하세요 : 1
#  HOT mocha : 3000원 주문이 추가되었습니다.
#
#  음료를 선택하세요 (0 입력 시 주문 종료)
# 음료의 번호를 입력하세요 : 0
#
# 🛒 주문이 완료되었습니다.
#
# ⟝-----------------------⟞
# |                       |
# |                       |
# | ICE americano   :  2000원 |
# | HOT mocha       :  3000원 |
# | 합계 금액           :  5000원 |
# |                       |
# |                       |
# ⟝-----------------------⟞
#
#
# 총 결제 금액은 5000원 입니다.
# 결제가 완료되었습니다. ☕ 감사합니다!
#
# ⟝-----------------------⟞
# |                       |
# |                       |
# | ICE americano   :  2000원 |
# | HOT mocha       :  3000원 |
# | 합계 금액           :  5000원 |
# |                       |
# |                       |
# ⟝-----------------------⟞
